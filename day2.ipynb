# %%
import pandas as pd

numbers = pd.Series([10, 20, 30, 40])
print(numbers)

# %%
data = {
    "Name": ["Ram", "Sita", "Hari"],
    "Age": [20, 21, 19]
}

df = pd.DataFrame(data)
print(df)

# %%
df = pd.read_csv("students.csv")

# %%
df.head()

# %%
df.info()

# %%
df["Name"]

# %%
df["Age"].mean()
