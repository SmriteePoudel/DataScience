# %%
#''' Pandas is used for EDA(Exploratory Data Analysis)
----------------------------------------------------------
#1. Condition Filtering
#2. Data Cleaning
#3. Data Extraction
#4. Feature Engineering
#5. Data Analysis
#6. Helps to visualize data

# %%
import pandas as pd

# %%
#Series (1D) and Dataframe(2D)

# %%
numbers = pd.Series([1,2,3,4,5,6,7])
numbers

# %%
'''num =[1,2,3,4,5,6,7]
for idx, val in enum(num):
    print(f'{idx}, {val})'''
#prints the same thing as above

# %%
#2D
personal_details= pd.DataFrame([['Ram',20,'ktm','Bachelors'],
['Hari',25,'bkt','Bachelors'],
['Ram',26,'ktm','Bachelors'],
['Shyam',23,'Lalitpur','+2'],
['Rita',26,'USA','Phd'],
['Gita',50,'jhapa','Bachelors']], columns= ['Name', 'Age','Address','Qualification'])

personal_details

# %%
personal_details[2:5]

# %%
#loc -> address
#iloc -> integer location

# %%
personal_details.iloc[1:6,2:]

# %%
personal_details.loc['1':'4','Name':'Address']

# %%
personal_details.iloc[
[1,3],
[2,3]
]
personal_details

# %%
personal_details.iloc[
[1,3],
[2,3]
]

# %%
#Data Read

# %%
#'''
#csv-> read_csv(file_name)
#excel-> read_excel(file_name)
#json-> read_json(file_name) '''

# %%
df = pd.read_csv('Dataset/Employees.csv')
df

# %%
df.head(10)

# %%
df.tail(10)
