# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset/Employees.csv')
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          100     Steven      King     SKING  515.123.4567  6/17/2003
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4          104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
#
#     JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# 0  AD_PRES   24000             NaN         NaN           90.0
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0
# 3  IT_PROG    9000             NaN       102.0           60.0
# 4  IT_PROG    6000             NaN       103.0           60.0

# %%
df['COMMISSION_PCT']=df['COMMISSION_PCT'].fillna(0.22)
df['MANAGER_ID']=df['MANAGER_ID'].fillna(100.0)
df['DEPARTMENT_ID']=df['DEPARTMENT_ID'].fillna(50.0)

# %%
df['MANAGER_ID']=df['MANAGER_ID'].astype(int)
df['DEPARTMENT_ID']=df['DEPARTMENT_ID'].astype(int)

# %%
df['HIRE_DATE']= pd.to_datetime(df['HIRE_DATE'])

# %%
''' 
GROUPBY()
AGGREGRATE func()
  1. mean()
  2. max()
  3. min()
  4. count()
  5. sum()

'''
# Out:
# ' \nGROUPBY()\nAGGREGRATE func()\n  1. mean()\n  2. max()\n  3. min()\n  4. count()\n  5. sum()\n\n'

# %%
#If you use groupby then aggregrate func must be used 
#If one uses aggregrate func then groupby clause is not mandatory

# %%
#variable = df.groupby(column1)[column2].count()

# %%
#variable = df.groupby(column1)

# %%
#Find total employees working in each departemt

# %%
#For formatting use // reset_index()
emp_dep = df.groupby('DEPARTMENT_ID')['EMPLOYEE_ID'].count().reset_index()
emp_dep
# Out:
#     DEPARTMENT_ID  EMPLOYEE_ID
# 0              10            1
# 1              20            2
# 2              30            6
# 3              40            2
# 4              50           46
# 5              60            5
# 6              70            2
# 7              80           34
# 8              90            3
# 9             100            6
# 10            110            4

# %%
#Formatting using markdown
emp_dep = df.groupby('DEPARTMENT_ID')['EMPLOYEE_ID'].count()

format_data = emp_dep.to_markdown(stralign='center', numalign= 'center')
print(format_data)
# Out:
# |  DEPARTMENT_ID  |  EMPLOYEE_ID  |
# |:---------------:|:-------------:|
# |       10        |       1       |
# |       20        |       2       |
# |       30        |       6       |
# |       40        |       2       |
# |       50        |      46       |
# |       60        |       5       |
# |       70        |       2       |
# |       80        |      34       |
# |       90        |       3       |
# |       100       |       6       |
# |       110       |       4       |

# %%
emp_dep = df.groupby('DEPARTMENT_ID')['EMPLOYEE_ID'].count().reset_index().rename(columns= {
     'EMPLOYEE_ID':'Count of employees', 'DEPARTMENT_ID':'Departments'
    
})

emp_dep
# Out:
#     Departments  Count of employees
# 0            10                   1
# 1            20                   2
# 2            30                   6
# 3            40                   2
# 4            50                  46
# 5            60                   5
# 6            70                   2
# 7            80                  34
# 8            90                   3
# 9           100                   6
# 10          110                   4

# %%
emp_dep = (
    df.groupby('DEPARTMENT_ID')['EMPLOYEE_ID']
      .count()
      .reset_index()
      .rename(columns={
          'EMPLOYEE_ID': 'Count of employees',
          'DEPARTMENT_ID': 'Departments'
      })
      .sort_values(by='Count of employees', ascending=True,ignore_index=True)#Professionally used otherwise use reset= True
)
emp_dep
# Out:
#     Departments  Count of employees
# 0            10                   1
# 1            20                   2
# 2            40                   2
# 3            70                   2
# 4            90                   3
# 5           110                   4
# 6            60                   5
# 7            30                   6
# 8           100                   6
# 9            80                  34
# 10           50                  46

# %%
#Fix index 
1. Check department total salary
2. job wise total employess
# Out:
#   Cell In[15], line 2
#     1. Check department total salary
#        ^
# SyntaxError: invalid syntax

# %%
job_emp = df.groupby('JOB_ID')['EMPLOYEE_ID'].count().reset_index().rename(columns= {'JOB_ID':'Job_Name','EMPLOYEE_ID':'Count of employee'})

# %%
job_filter= job_emp['Count of employee'] > 2
job_emp[job_filter]

# %%
total_salary=df.groupby('DEPARTMENT_ID')['SALARY'].sum().reset_index().rename(columns = {'DEPARTMENT_ID':'Member of department','SALARY':'Salary'}).sort_values(ascending= False, by = 'Salary', ignore_index= True)

# %%
total_salary.head()

# %%
dep_job = (
    df.groupby(['DEPARTMENT_ID', 'JOB_ID'])['SALARY']
      .sum()
      .reset_index()
      .rename(columns={'DEPARTMENT_ID': 'dept', 'JOB_ID': 'job'})
)
dep_job

# %%
dep_job_report = (
    df.groupby(['DEPARTMENT_ID', 'JOB_ID'])
      .agg(Total_Salary=('SALARY', 'sum'))
      .reset_index()
)

print(dep_job_report)

# %%
dep_job_report['Total_Salary'] = dep_job_report['Total_Salary'].map("Rs.{:,.2f}".format)
dep_job_report

# %%
columns = ['Max_Salary', 'Min_Salary', 'Avg Salary']

for col in columns:
    dep_job_report[col] = dep_job_report[col].map("Rs.{:,.2f}".format)

# %%
dep_job_report.style.set_table_styles([
    {
        'selector': 'th',
        'props': [('text-align', 'center')]
    },
    {
        'selector': 'td',
        'props': [('text-align', 'center')]
    }
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dep_job_report.style.set_table_styles([
#       2     {
#       3         'selector': 'th',
#       4         'props': [('text-align', 'center')]
#       5     },
#       6     {
#       7         'selector': 'td',
#       8         'props': [('text-align', 'center')]
#       9     }
#      10 ])
#
# NameError: name 'dep_job_report' is not defined

# %%
Date Time
--------
Time Intelligence Function

MoM-> Month Over Month Growth
YoY->Year Over Year Growth

PMTD -> Previous Month to Date
PYTD -> Previous Year to Date

CMTD -> Current Month to Date
CYTD -> Current Year to Date
# Out:
#   Cell In[27], line 1
#     Date Time
#          ^
# SyntaxError: invalid syntax

# %%
df['HIRE_DATE']= pd.to_datetime(df['HIRE_DATE'])

# %%
df['HIRE_DATE'] = pd.to_datetime(df['HIRE_DATE'])

df['HIRE_YEAR'] = df['HIRE_DATE'].dt.year
df['HIRE_MONTH'] = df['HIRE_DATE'].dt.month_name()
df['HIRE_DAY'] = df['HIRE_DATE'].dt.day_name()

# %%
df
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567 2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567 2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568 2007-05-21
# ..           ...        ...       ...       ...           ...        ...
# 106          206    William     Gietz    WGIETZ  515.123.8181 2002-06-07
# 107          203      Susan    Mavris   SMAVRIS  515.123.7777 2002-06-07
# 108          204    Hermann      Baer     HBAER  515.123.8888 2002-06-07
# 109          205    Shelley   Higgins  SHIGGINS  515.123.8080 2002-06-07
# 110          206    William     Gietz    WGIETZ  515.123.8181 2002-06-07
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID  HIRE_YEAR  \
# 0       AD_PRES   24000            0.22         100             90       2003
# 1         AD_VP   17000            0.22         100             90       2005
# 2         AD_VP   17000            0.22         100             90       2001
# 3       IT_PROG    9000            0.22         102             60       2006
# 4       IT_PROG    6000            0.22         103             60       2007
# ..          ...     ...             ...         ...            ...        ...
# 106  AC_ACCOUNT    8300            0.22         205            110       2002
# 107      HR_REP    6500            0.22         101             40       2002
# 108      PR_REP   10000            0.22         101             70       2002
# 109      AC_MGR   12008            0.22         101            110       2002
# 110  AC_ACCOUNT    8300            0.22         205            110       2002
#
#     HIRE_MONTH   HIRE_DAY
# 0         June    Tuesday
# 1    September  Wednesday
# 2      January   Saturday
# 3      January    Tuesday
# 4          May     Monday
# ..         ...        ...
# 106       June     Friday
# 107       June     Friday
# 108       June     Friday
# 109       June     Friday
# 110       June     Friday
#
# [111 rows x 14 columns]

# %%
''' 
1. Find total employees hired in each day.
2. Find total employees hired in each month.
'''
# Out:
# ' \n1. Find total employees hired in each day.\n2. Find total employees hired in each month.\n'

# %%
weekdays=['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']
df['HIRE_DAY']= pd.Categorical(df['HIRE_DAY'],categories = weekdays)

# %%
emp_day = df.groupby(df['HIRE_DAY'], observed= False)['EMPLOYEE_ID'].count().reset_index()
emp_day
# Out:
#     HIRE_DAY  EMPLOYEE_ID
# 0     Sunday           15
# 1     Monday           10
# 2    Tuesday           13
# 3  Wednesday           15
# 4   Thursday           16
# 5     Friday           23
# 6   Saturday           19

# %%
df['HIRE_MONTH_NUM']=df['HIRE_DATE'].dt.month

# %%
month_emp= df.groupby(['HIRE_MONTH','HIRE_MONTH_NUM'])['EMPLOYEE_ID'].count().reset_index()
month_emp
# Out:
#    HIRE_MONTH  HIRE_MONTH_NUM  EMPLOYEE_ID
# 0       April               4            7
# 1      August               8            9
# 2    December              12            7
# 3    February               2           13
# 4     January               1           14
# 5        July               7            7
# 6        June               6           15
# 7       March               3           17
# 8         May               5            6
# 9    November              11            5
# 10    October              10            6
# 11  September               9            5

# %%
month_emp= df.groupby(['HIRE_MONTH_NUM','HIRE_MONTH'])['EMPLOYEE_ID'].count().reset_index()
month_emp
# Out:
#     HIRE_MONTH_NUM HIRE_MONTH  EMPLOYEE_ID
# 0                1    January           14
# 1                2   February           13
# 2                3      March           17
# 3                4      April            7
# 4                5        May            6
# 5                6       June           15
# 6                7       July            7
# 7                8     August            9
# 8                9  September            5
# 9               10    October            6
# 10              11   November            5
# 11              12   December            7

# %%
month_emp = df.groupby(['HIRE_MONTH_NUM', 'HIRE_MONTH']).agg(
    Total_Employees=('EMPLOYEE_ID', 'count')
).reset_index()

month_data = month_emp[['HIRE_MONTH', 'Total_Employees']]

# %%
df['HIRE_YEAR'].unique()
# Out:
# array([2003, 2005, 2001, 2006, 2007, 2002, 2004, 2008])

# %%
year_data=df.groupby('HIRE_YEAR').count().reset_index()

# %% [markdown]
# cmtd = (year_data['Hire_YEAR']==2008)
# year_data[smtd]

# %%
pmtd = (year_data['HIRE_YEAR'] == 2007)

pmtd_data = year_data[pmtd]

pmtd_data
# Out:
#    HIRE_YEAR  EMPLOYEE_ID  FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  \
# 6       2007           19          19         19     19            19
#
#    HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID  \
# 6         19      19      19              19          19             19
#
#    HIRE_MONTH  HIRE_DAY  HIRE_MONTH_NUM
# 6          19        19              19

# %%
cmtd = (year_data['HIRE_YEAR'] == 2007)

cmtd_data = year_data[cmtd]

cmtd_data
# Out:
#    HIRE_YEAR  EMPLOYEE_ID  FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  \
# 6       2007           19          19         19     19            19
#
#    HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID  \
# 6         19      19      19              19          19             19
#
#    HIRE_MONTH  HIRE_DAY  HIRE_MONTH_NUM
# 6          19        19              19

# %%
year_data = df.groupby('HIRE_YEAR')['EMPLOYEE_ID'].count().reset_index()

# %%
year_data['YoY_Growth']=year_data['EMPLOYEE_ID'].pct_change()

# %%
year_data['YoY%'] = year_data['YoY_Growth']*100

# %%
month_data['MoM_Growth']=month_data['Total_Employees'].pct_change()
month_data['YoY%'] = month_data['MoM_Growth']*100

# %%
#(current_date - previous_date)/ total_number_of_data
