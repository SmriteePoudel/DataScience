# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset/Fraud Detection Dataset.csv')
df.head()
# Out:
#   Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0             T1     4174             1292.76   ATM Withdrawal
# 1             T2     4507             1554.58   ATM Withdrawal
# 2             T3     1860             2395.02   ATM Withdrawal
# 3             T4     2294              100.10     Bill Payment
# 4             T5     2130             1490.50      POS Payment
#
#    Time_of_Transaction Device_Used       Location  \
# 0                 16.0      Tablet  San Francisco
# 1                 13.0      Mobile       New York
# 2                  NaN      Mobile            NaN
# 3                 15.0     Desktop        Chicago
# 4                 19.0      Mobile  San Francisco
#
#    Previous_Fraudulent_Transactions  Account_Age  \
# 0                                 0          119
# 1                                 4           79
# 2                                 3          115
# 3                                 4            3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51000 entries, 0 to 50999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Transaction_ID                    51000 non-null  object
#  1   User_ID                           51000 non-null  int64
#  2   Transaction_Amount                48480 non-null  float64
#  3   Transaction_Type                  51000 non-null  object
#  4   Time_of_Transaction               48448 non-null  float64
#  5   Device_Used                       48527 non-null  object
#  6   Location                          48453 non-null  object
#  7   Previous_Fraudulent_Transactions  51000 non-null  int64
#  8   Account_Age                       51000 non-null  int64
#  9   Number_of_Transactions_Last_24H   51000 non-null  int64
#  10  Payment_Method                    48531 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Transaction_ID                         0
# User_ID                                0
# Transaction_Amount                  2520
# Transaction_Type                       0
# Time_of_Transaction                 2552
# Device_Used                         2473
# Location                            2547
# Previous_Fraudulent_Transactions       0
# Account_Age                            0
# Number_of_Transactions_Last_24H        0
# Payment_Method                      2469
# Fraudulent                             0
# dtype: int64

# %%
df['Time_of_Transaction'].unique() #-> put 0 as time
# Out:
# array([16., 13., nan, 15., 19.,  2.,  3., 20.,  0., 12., 21., 14.,  7.,
#         4., 17., 10.,  5.,  8., 11., 18.,  1., 22.,  9.,  6., 23.])

# %%
df['Device_Used'].unique() #-> unknown data
# Out:
# array(['Tablet', 'Mobile', 'Desktop', nan, 'Unknown Device'], dtype=object)

# %%
df['Location'].unique() #-> unknown data
# Out:
# array(['San Francisco', 'New York', nan, 'Chicago', 'Boston', 'Houston',
#        'Miami', 'Los Angeles', 'Seattle'], dtype=object)

# %% [raw]
# #Add

# %%
df['Payment_Method'].unique() #-> Unknown data
# Out:
# array(['Debit Card', 'Credit Card', nan, 'UPI', 'Net Banking',
#        'Invalid Method'], dtype=object)

# %%
df['Time_of_Transaction']=df['Time_of_Transaction'].fillna(0)

# %%
df['Device_Used']=df['Device_Used'].fillna('un')

# %%
df['Location']=df['Location'].fillna('un')

# %%
df['Payment_Method']=df['Payment_Method'].fillna('un')

# %%
df['Time_of_Transaction']=df['Time_of_Transaction'].astype(int)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51000 entries, 0 to 50999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Transaction_ID                    51000 non-null  object
#  1   User_ID                           51000 non-null  int64
#  2   Transaction_Amount                48480 non-null  float64
#  3   Transaction_Type                  51000 non-null  object
#  4   Time_of_Transaction               51000 non-null  int32
#  5   Device_Used                       51000 non-null  object
#  6   Location                          51000 non-null  object
#  7   Previous_Fraudulent_Transactions  51000 non-null  int64
#  8   Account_Age                       51000 non-null  int64
#  9   Number_of_Transactions_Last_24H   51000 non-null  int64
#  10  Payment_Method                    51000 non-null  object
# ...

# %%
 ''' Remove Unwanted data
1. "   abc nidanjmczx   " -> White Spaces
2. !#()&{}[]+?:;" -> special characters/ Regex(Regular Expression)
 
 '''
# Out:
# 'Remove Unwanted data'

# %%
 ''' #String Function 
---------------
1. replace -> 
2. strip(), LStrip(), RStrip() -> remove white strip, left & right

''''
