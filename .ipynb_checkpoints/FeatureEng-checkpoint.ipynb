# %%
#Feature Engineering

import pandas as pd

# %%
df = pd.read_csv('Dataset/HR_Dataset Refresh.csv')
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df['Employee_Name'] = df['Employee_Name'].str.replace(',', ' ',regex=False)
df
# Out:
#                Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi Wilson  K  10026          0                0         1
# 1    Ait Sidi Karthikeyan     10084          1                1         1
# 2           Akinkuolie Sarah  10196          1                1         0
# 3                AlagbeTrina  10088          1                1         0
# 4            Anderson Carol   10069          0                2         0
# ..                       ...    ...        ...              ...       ...
# 577          Anderson Carol   10069          0                2         0
# 578         Anderson Linda    10002          0                0         0
# 579           Andreola Colby  10194          0                0         0
# 580               Athwal Sam  10062          0                4         1
# 581          Bachiochi Linda  10114          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# ...

# %%
#To break column use split(find value,(n) no of column= index,expand=True)

# %%
df[['last_name','first_name','middle_name']] = df['Employee_Name'].str.split(' ', n=2, expand = True)
df
# Out:
#                Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi Wilson  K  10026          0                0         1
# 1    Ait Sidi Karthikeyan     10084          1                1         1
# 2           Akinkuolie Sarah  10196          1                1         0
# 3                AlagbeTrina  10088          1                1         0
# 4            Anderson Carol   10069          0                2         0
# ..                       ...    ...        ...              ...       ...
# 577          Anderson Carol   10069          0                2         0
# 578         Anderson Linda    10002          0                0         0
# 579           Andreola Colby  10194          0                0         0
# 580               Athwal Sam  10062          0                4         1
# 581          Bachiochi Linda  10114          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# ...

# %%
'''
#Fix it 
1. First Name 
2. Second Name
3. Middle Name manage the row '''
